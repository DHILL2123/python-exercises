# %%
import pandas as pd

df = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv')

# %% [markdown]
# ## Discussion
#
#
# 1. What is a dataframe?
# ###A DataFrame is a data structure that organizes data into a 2-dimensional table of rows and columns,
# ###much like a spreadsheet
#
# 2. What information can we obtain about a dataframe?
# ##The information contains the number of columns, column labels, column data types, memory usage,
# ##range index, and the number of cells in each column (non-null values).
# ##Note: the info() method actually prints the info.
#
# 3. How have we interacted with a dataframe?
# ##Answered questions based on the data.

# %% [markdown]
# #Practice Exercises¶
# Information about a dataframe
#
# Obtain the following information:
# dimensions
# dtypes
# column names
# summary statistics
#
# Working with dataframes
#
# What is the highest HP value present?
# Create a function named highest_attack.
# Use the loaded dataframe as an argument.
#
# Which Pokemon possess(es) the highest HP value?
#
# How many different types are represented in Type 1?
# Create a function named num_types
# Use the loaded dataframe as an argument
#
# Number of Pokemon whose Type 2 is Ghost
#
# Percentage of Pokemon whose Type 2 is Ghost
# Create a function named percent_ghost
# Use the loaded dataframe as an argument
#
# Number of Pokemon whose Attack is greater than Defense
#
# Lowest speed for Grass or Rock
#
# Change all the column names
# lowercase letters
# remove whitespace
#
# Rename Sp. Attack to special-attack
#
# Rename Sp. Def to special-defense
#
# Which Pokemon has/have the greatest difference in:
# Attack and Defense points
# Special Attack and Special Defense
#
# How many Pokemon are of Type 1 Rock and Type 2 Fairy?
#
# Which Fire Pokemon appears last alphabetically?
# Create a function named last_pokemon
# Use the loaded dataframe as an argument
#
# Bonus
#
# Find the average speed by Generation
#
# Create a function which acccepts:
# a dataframe
# two different Pokemon stats e.g. Attack and Defense
#
# The function will:
# Calculate difference between the two given Pokemon stats
# Create a column which contains the difference of the two given Pokemon stats named stats-diff

# %% [markdown]
# Information about a dataframe¶
# Obtain the following information:
# dimensions
# dtypes
# column names
# summary statistics

# %%
df.shape
# Out:
# (800, 13)

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# What is the highest HP value present?
# Create a function named highest_attack.
# Use the loaded dataframe as an argument.

# %%
df.HP.max()
# Out:
# 255

# %%
Name = df
def highest_attack(Name):
    
    df[['Name','Attack']].max()
    
    return df[['Name','Attack']].max()

# %%
highest_attack(Name)
# Out:
# Name      Zygarde50% Forme
# Attack                 190
# dtype: object

# %% [markdown]
# Which Pokemon possess(es) the highest HP value?

# %%
df[['Name', "HP"]].max()
# Out:
# Name    Zygarde50% Forme
# HP                   255
# dtype: object

# %% [markdown]
# How many different types are represented in Type 1?
# Create a function named num_types
# Use the loaded dataframe as an argument

# %%
df['Type 1'].nunique()
# Out:
# 18

# %%
type1 = df
def num_types(type1):
    df['Type 1'].nunique()
    return df['Type 1'].nunique()

# %%
num_types(type1)
# Out:
# 18

# %% [markdown]
# Number of Pokemon whose Type 2 is Ghost

# %%
df[df['Type 2']=='Ghost']['Type 2'].count()
# Out:
# 14

# %% [markdown]
# Percentage of Pokemon whose Type 2 is Ghost
# Create a function named percent_ghost
# Use the loaded dataframe as an argument

# %%
df[df['Type 2']=='Ghost']['Type 2'].count()
# Out:
# 14

# %%
df[['Type 2']].count()
# Out:
# Type 2    414
# dtype: int64

# %%
df[df['Type 2']=='Ghost']['Type 2'].count() / df[['Type 2']].count()
# Out:
# Type 2    0.033816
# dtype: float64

# %%
ghost = df[df['Type 2']=='Ghost']['Type 2'].count() / df[['Type 2']].count()
def percent_ghost(ghost):
    df[df['Type 2']=='Ghost']['Type 2'].count() / df[['Type 2']].count()
    return ghost

# %%
percent_ghost(ghost)
# Out:
# Type 2    0.033816
# dtype: float64

# %% [markdown]
# Number of Pokemon whose Attack is greater than Defense

# %%
mask = df.Attack > df.Defense
len(df[mask])
# Out:
# 445

# %%
mask.sum()
# Out:
# 445

# %% [markdown]
# Lowest speed for Grass or Rock

# %%
df[df['Type 1']=='Grass'].Speed.min()
# Out:
# 10

# %%
df[df['Type 1']=='Rock'].Speed.min()
# Out:
# 10

# %% [markdown]
# Change all the column names
# lowercase letters
# remove whitespace

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49        5
# 1      2                Ivysaur    Grass  Poison    405  60      62        5
# 2      3               Venusaur    Grass  Poison    525  80      82       10
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100       15
# 4      4             Charmander     Fire     NaN    309  39      52       15
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      200
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      200
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110      230
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160      230
# 799  721              Volcanion     Fire   Water    600  80     110      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#rename columns
df.rename(columns={"name": 'Name'})
# Out:
#        #                   Name   type 1  type 2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      sp. atk  sp. def  speed  generation  legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#Makes all columns lowercase
df.columns = map(str.lower, df.columns)

# %%
df
# Out:
#        #                   name   type 1  type 2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      sp. atk  sp. def  speed  generation  legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
#To remove white space everywhere:
df.columns = df.columns.str.replace(' ', '')

# %%
df
# Out:
#        #                   name    type1   type2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      sp.atk  sp.def  speed  generation  legendary
# 0        65      65     45           1      False
# 1        80      80     60           1      False
# 2       100     100     80           1      False
# 3       122     120     80           1      False
# 4        60      50     65           1      False
# ..      ...     ...    ...         ...        ...
# 795     100     150     50           6       True
# 796     160     110    110           6       True
# 797     150     130     70           6       True
# 798     170     130     80           6       True
# 799     130      90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Rename Sp. Attack to special-attack

# %%
#rename one column
df = df.rename(columns={'sp.atk':'special-attack'})

# %%
df
# Out:
#        #                   name    type1   type2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      special-attack  sp.def  speed  generation  legendary
# 0                65      65     45           1      False
# 1                80      80     60           1      False
# 2               100     100     80           1      False
# 3               122     120     80           1      False
# 4                60      50     65           1      False
# ..              ...     ...    ...         ...        ...
# 795             100     150     50           6       True
# 796             160     110    110           6       True
# 797             150     130     70           6       True
# 798             170     130     80           6       True
# 799             130      90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Rename Sp. Def to special-defense

# %%
#rename one column
df = df.rename(columns={'sp.def':'special-defense'})

# %%
df
# Out:
#        #                   name    type1   type2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      special-attack  special-defense  speed  generation  legendary
# 0                65               65     45           1      False
# 1                80               80     60           1      False
# 2               100              100     80           1      False
# 3               122              120     80           1      False
# 4                60               50     65           1      False
# ..              ...              ...    ...         ...        ...
# 795             100              150     50           6       True
# 796             160              110    110           6       True
# 797             150              130     70           6       True
# 798             170              130     80           6       True
# 799             130               90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Which Pokemon has/have the greatest difference in:
# Attack and Defense points
# Special Attack and Special Defense

# %%
#Attack and Defense points
df.attack - df.defense
# Out:
# 0        0
# 1       -1
# 2       -1
# 3      -23
# 4        9
#       ...
# 795    -50
# 796     50
# 797     50
# 798    100
# 799    -10
# Length: 800, dtype: int64

# %%
#Attack and Defense points
df['addif']= df.attack - df.defense

# %%
df[['name','attack','defense', 'addif']].groupby(by='addif').max()
# Out:
#                         name  attack  defense
# addif
# -220                 Shuckle      10      230
# -116               Bastiodon      52      168
# -115                 Steelix      85      200
# -105     SteelixMega Steelix     125      230
# -100                Regirock     100      200
# ...                      ...     ...      ...
#  90      MewtwoMega Mewtwo X     190      100
#  100      HoopaHoopa Unbound     160       60
#  105               Rampardos     165       60
#  110   BeedrillMega Beedrill     150       40
#  160      DeoxysAttack Forme     180       20
#
# [121 rows x 3 columns]

# %%
df
# Out:
#        #                   name    type1   type2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      special-attack  special-defense  speed  generation  legendary  addif
# 0                65               65     45           1      False      0
# 1                80               80     60           1      False     -1
# 2               100              100     80           1      False     -1
# 3               122              120     80           1      False    -23
# 4                60               50     65           1      False      9
# ..              ...              ...    ...         ...        ...    ...
# 795             100              150     50           6       True    -50
# 796             160              110    110           6       True     50
# 797             150              130     70           6       True     50
# 798             170              130     80           6       True    100
# 799             130               90     70           6       True    -10
#
# [800 rows x 14 columns]

# %%
#Special Attack and Special Defense
df['spad']= df['special-attack']- df['special-defense']

# %%
df[['name','special-attack','special-defense','spad']].groupby('spad').max()
# Out:
#                        name  special-attack  special-defense
# spad
# -220                Shuckle              10              230
# -100                 Regice             100              200
# -91               Bastiodon              47              138
# -90     DeoxysDefense Forme              70              160
# -75               Registeel              75              150
# ...                     ...             ...              ...
#  74     MewtwoMega Mewtwo Y             194              120
#  75       GengarMega Gengar             170               95
#  80   RayquazaMega Rayquaza             180              100
#  100     DeoxysNormal Forme             150               50
#  160     DeoxysAttack Forme             180               20
#
# [104 rows x 3 columns]

# %% [markdown]
# How many Pokemon are of Type 1 Rock and Type 2 Fairy?

# %%
#How many Pokemon are of Type 1 Rock and Type 2 Fairy?
df[df['type1']=='Rock'][df['type2']=='Fairy'].count()
# Out:
# /var/folders/nl/h7bb3qxn0s5dcp9j1thjq_4h0000gn/T/ipykernel_27774/1355116956.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['type1']=='Rock'][df['type2']=='Fairy'].count()
# #                  3
# name               3
# type1              3
# type2              3
# total              3
# hp                 3
# attack             3
# defense            3
# special-attack     3
# special-defense    3
# speed              3
# generation         3
# legendary          3
# addif              3
# spad               3
# dtype: int64

# %%
#How many Pokemon are of Type 1 Rock and Type 2 Fairy?
df[df['type2']=='Fairy'].groupby(by='type1').count()
# Out:
#           #  name  type2  total  hp  attack  defense  special-attack  \
# type1
# Dragon    1     1      1      1   1       1        1               1
# Electric  1     1      1      1   1       1        1               1
# Grass     2     2      2      2   2       2        2               2
# Normal    5     5      5      5   5       5        5               5
# Psychic   6     6      6      6   6       6        6               6
# Rock      3     3      3      3   3       3        3               3
# Steel     3     3      3      3   3       3        3               3
# Water     2     2      2      2   2       2        2               2
#
#           special-defense  speed  generation  legendary  addif  spad
# type1
# Dragon                  1      1           1          1      1     1
# Electric                1      1           1          1      1     1
# Grass                   2      2           2          2      2     2
# Normal                  5      5           5          5      5     5
# Psychic                 6      6           6          6      6     6
# Rock                    3      3           3          3      3     3
# Steel                   3      3           3          3      3     3
# Water                   2      2           2          2      2     2

# %% [markdown]
# Which Fire Pokemon appears last alphabetically?
# Create a function named last_pokemon
# Use the loaded dataframe as an argument

# %%
def last_pokemon():

# %%
df.sort_values(['name','type1','type2'], ascending = True)
# Out:
#        #                     name    type1   type2  total   hp  attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      defense  special-attack  special-defense  speed  generation  legendary  \
# 510       75              92               85     60           4      False
# 511      105             132              105     30           4      False
# 68        15             105               55     90           1      False
# 392       60              75               60     75           3      False
# 393       60             115               60    115           3      False
# ..       ...             ...              ...    ...         ...        ...
# 632       60             120               60    105           5      False
# 631       40              80               40     65           5      False
# 46        35              30               40     55           1      False
# 695       70              65               70     58           5      False
# 794      121              81               95     95           6       True
#
#      addif  spad
# 510     17     7
# 511     27    27
# 68       5    50
# 392     70    15
# 393     90    55
# ..     ...   ...
# 632     45    60
# 631     25    40
# 46      10   -10
# 695     15    -5
# 794    -21   -14
#
# [800 rows x 15 columns]

# %%
df[df['type2']=='Fire'].groupby(by='type1').max()
# Out:
#             #                   name type2  total   hp  attack  defense  \
# type1
# Dragon    643               Reshiram  Fire    680  100     120      100
# Electric  479        RotomHeat Rotom  Fire    520   50      65      107
# Ghost     609                Litwick  Fire    520   60      55       90
# Ground    383  GroudonPrimal Groudon  Fire    770  100     180      160
# Psychic   494                Victini  Fire    600  100     100      100
#
#           special-attack  special-defense  speed  generation  legendary  \
# type1
# Dragon               150              120     90           5       True
# Electric             105              107     86           4      False
# Ghost                145               90     80           5      False
# Ground               150               90     90           3       True
# Psychic              100              100    100           5       True
#
#           addif  spad
# type1
# Dragon       20    30
# Electric    -42    -2
# Ghost       -20    55
# Ground       20    60
# Psychic       0     0

# %%
df[df['type1']=='Fire'][df['type2']=='Fire']
# Out:
# /var/folders/nl/h7bb3qxn0s5dcp9j1thjq_4h0000gn/T/ipykernel_27774/1377684578.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['type1']=='Fire'][df['type2']=='Fire']
# Empty DataFrame
# Columns: [#, name, type1, type2, total, hp, attack, defense, special-attack, special-defense, speed, generation, legendary, addif, spad]
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [374], in <cell line: 1>()
# ----> 1 df[['name'[df['type1']=='Fire']]]
#
# TypeError: string indices must be integers
